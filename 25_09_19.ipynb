# %%
name='홍길동'
age=18

# %%
print(name)
# Out:
# 홍길동

# %%
print(age)
# Out:
# 18

# %%
name
# Out:
# '홍길동'

# %%
age
# Out:
# 18

# %%
c=10

# %%
b=c

# %%
a=b

# %%
print(a,b,c)
# Out:
# 10 10 10

# %%
a+=10

# %%
print(a)
# Out:
# 20

# %%
_age=100

# %%
Age=100

# %%
age=10

# %%
Age
# Out:
# 100

# %%
age
# Out:
# 10

# %%
a=7
b=11

# %%
a
# Out:
# 7

# %%
b
# Out:
# 11

# %%
c=a
a=b
b=c

# %%
a
# Out:
# 11

# %%
b
# Out:
# 7

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
height=180.5

# %%
type(height)
# Out:
# float

# %%
flag=True

# %%
type(flag)
# Out:
# bool

# %%
a=20
b=0o34
c=0xA1
d=0b1110

# %%
print(a)
print(b)
print(c)
print(d)
# Out:
# 20
# 28
# 161
# 14

# %%
a=10

# %%
b=20

# %%
c, d=30, 40

# %%
c
# Out:
# 30

# %%
d
# Out:
# 40

# %%
a=10>20

# %%
a
# Out:
# False

# %%
type(a)
# Out:
# bool

# %%
a='Python'

# %%
a='HI'+'Python'

# %%
a
# Out:
# 'HIPython'

# %%
a=10
b='10'

# %%
c=a+float(b)
print(c)
# Out:
# 20.0

# %%
int(c)
# Out:
# 20

# %%
name=input('이름을 입력')
age=input('나이를 입력')
# Out:
# 이름을 입력홍길동
# 나이를 입력18

# %%
age
# Out:
# '18'

# %%
name
# Out:
# '홍길동'

# %%
type(age)
# Out:
# str

# %%
int(age)
# Out:
# 18

# %%
age=int(age)+2

# %%
age
# Out:
# 20

# %%
a=int(input())
b=int(input())
c=a-b
print(c)
print(a,b,c)
print(a)
print(b)
print(c)
# Out:
# 5
# 4
# 1
# 5 4 1
# 5
# 4
# 1

# %%
r=int(input('반지름을 입력하세요 : '))
S=r*r
print(S)
# Out:
# 반지름을 입력하세요 : 3
# 9
